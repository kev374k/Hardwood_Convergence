# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
player_data = pd.read_csv('files/players.csv')

# %%
game_details = pd.read_csv('files/games_details.csv')
full_games = pd.read_csv('files/games.csv')
# Out:
# /var/folders/lz/89b0m93557x4pjgtj7v1dcpc0000gn/T/ipykernel_65222/1022933188.py:1: DtypeWarning: Columns (6,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   game_details = pd.read_csv('files/games_details.csv')

# %% [markdown]
# Removes all NA or None values in the columns when a player didn't play, or when a player had a DNP

# %%
for col in game_details.columns:
    if col in ['MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS', 'PLUS_MINUS']:
        game_details[col] = game_details.get(col).fillna(0)

# %%
def game_score_formula(pts, fg, fga, fta, ft, orb, drb, stl, ast, blk, pf, tov):
    """ 
    A measure of how well a player is doing in a single game.
    Created by John Hollinger to give rough measure of how well each
    singular player did in a game(40 is a great game, 10 is average)
    """
    return (pts) + (0.4 * fg) - (0.7 * fga) + (0.4 * (fta-ft)) + (0.7 * orb) + (0.3 * drb) + stl + (0.7 * ast) + (0.7 * blk) - (0.4 * pf) - tov

# %%
game_score_req = np.array(['PTS', 'FGM', 'FGA', 'FTA', 'FTM', 'OREB', 'DREB', 'STL', 'AST', 'BLK', 'PF', 'TO'])
score_reqs = game_details.get(game_score_req)

# %% [markdown]
# Get info on whether columns within game_details are integers, objects, floats, or anything else that is necessary

# %% [markdown]
# In game details, the columns that are necessary for data analysis are TEAM_ABBREVIATION, PLAYER_NAME, START_POSITION, MIN, FGM, FGA. FG_PCT, FG3M, FG3A, FG_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TO, PF, PTS, PLUS_MINUS, and GAME_SCORE
#
# We adjust the MIN column to actual minutes, and add the GAME_SCORE column to calculate game score

# %%
game_details['GAME_SCORE'] = score_reqs.get(game_score_req).apply(lambda x: game_score_formula(*x), axis = 1)
game_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  DREB  REB  AST  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0  2.0  0.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   3.0  9.0  6.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   3.0  4.0  1.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   9.0  9.0  5.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   2.0  2.0  3.0
#
#    STL  BLK   TO   PF   PTS PLUS_MINUS  GAME_SCORE
# 0  1.0  0.0  2.0  5.0   2.0       -2.0        -0.3
# 1  1.0  0.0  2.0  1.0  23.0      -14.0        25.1
# 2  1.0  0.0  2.0  4.0  13.0       -4.0         8.8
# 3  3.0  0.0  2.0  1.0  10.0      -18.0         9.3
# 4  0.0  0.0  2.0  2.0  19.0        0.0        13.3
#
# [5 rows x 30 columns]

# %% [markdown]
# Creates dataframe 'necessary_data' that are needed to find out who the best players in games typically are, based on sorting by each game and finding out the 5 players who had the best game score are.

# %%
necessary_data = game_details.drop(['TEAM_ID', 'TEAM_CITY', 'PLAYER_ID', 'FG3_PCT', 'NICKNAME', 'COMMENT'], axis = 1)
necessary_data.head()
# Out:
#     GAME_ID TEAM_ABBREVIATION     PLAYER_NAME START_POSITION    MIN  FGM  \
# 0  22200477               SAS  Romeo Langford              F  18:06  1.0
# 1  22200477               SAS   Jeremy Sochan              F  31:01  7.0
# 2  22200477               SAS    Jakob Poeltl              C  21:42  6.0
# 3  22200477               SAS   Devin Vassell              G  30:20  4.0
# 4  22200477               SAS       Tre Jones              G  27:44  7.0
#
#     FGA  FG_PCT  FG3M  FG3A  ...  DREB  REB  AST  STL  BLK   TO   PF   PTS  \
# 0   1.0   1.000   0.0   0.0  ...   1.0  2.0  0.0  1.0  0.0  2.0  5.0   2.0
# 1  14.0   0.500   2.0   4.0  ...   3.0  9.0  6.0  1.0  0.0  2.0  1.0  23.0
# 2   9.0   0.667   0.0   0.0  ...   3.0  4.0  1.0  1.0  0.0  2.0  4.0  13.0
# 3  13.0   0.308   1.0   6.0  ...   9.0  9.0  5.0  3.0  0.0  2.0  1.0  10.0
# 4  12.0   0.583   1.0   3.0  ...   2.0  2.0  3.0  0.0  0.0  2.0  2.0  19.0
#
#    PLUS_MINUS  GAME_SCORE
# 0        -2.0        -0.3
# 1       -14.0        25.1
# 2        -4.0         8.8
# 3       -18.0         9.3
# 4         0.0        13.3
#
# [5 rows x 24 columns]

# %% [markdown]
# Tried to find out the best 5 players in every single game depending on their game score. Sorted through the GAME_ID(s)(for individual games), and found out their game score and sorted based on the five highest

# %%
best_players_by_game_score = pd.DataFrame(columns = necessary_data.columns)

# %%
for game_id in full_games[full_games.get('GAME_DATE_EST').str.contains('2022|2021|2020')].get('GAME_ID'):
    best_players_by_game_score = pd.concat([best_players_by_game_score, necessary_data[necessary_data.get('GAME_ID') == game_id].sort_values('GAME_SCORE', ascending = False).head(5)])

# %%
necessary_data[necessary_data.get('GAME_ID') == game_id].sort_values('GAME_SCORE', ascending = False).head(5)
# Out:
#          GAME_ID TEAM_ABBREVIATION      PLAYER_NAME START_POSITION    MIN  \
# 101755  21900507               LAL     LeBron James              F  38:04
# 101742  21900507               PHX  Kelly Oubre Jr.              F  36:19
# 101756  21900507               LAL    Anthony Davis              F  37:55
# 101745  21900507               PHX     Devin Booker              G  37:14
# 101759  21900507               LAL    Avery Bradley              G  30:04
#
#          FGM   FGA  FG_PCT  FG3M  FG3A  ...  DREB   REB   AST  STL  BLK   TO  \
# 101755  11.0  21.0   0.524   1.0   4.0  ...  11.0  13.0  12.0  2.0  1.0  5.0
# 101742   9.0  14.0   0.643   3.0   5.0  ...   3.0   6.0   3.0  3.0  0.0  1.0
# 101756   9.0  16.0   0.563   1.0   3.0  ...  10.0  11.0   2.0  0.0  1.0  3.0
# 101745  11.0  23.0   0.478   1.0   3.0  ...   2.0   2.0   7.0  1.0  0.0  6.0
# 101759   9.0  11.0   0.818   0.0   2.0  ...   4.0   5.0   1.0  3.0  0.0  1.0
#
#          PF   PTS  PLUS_MINUS  GAME_SCORE
# 101755  0.0  31.0        18.0        33.1
# 101742  4.0  26.0       -16.0        26.5
# 101756  1.0  26.0        16.0        21.2
# 101745  3.0  32.0       -13.0        20.0
# 101759  2.0  18.0        23.0        17.7
#
# [5 rows x 24 columns]

# %% [markdown]
# From 2020-2022, who are the players that have been the most consistent(i.e. which players have had the most top 5 gamescores in their games?)

# %%
game_score_players = best_players_by_game_score.groupby('PLAYER_NAME').count().sort_values('GAME_ID', ascending = False).head(100)
game_score_players
# Out:
#                        GAME_ID  TEAM_ABBREVIATION  START_POSITION  MIN  FGM  \
# PLAYER_NAME
# Nikola Jokic               234                234             234  234  234
# Giannis Antetokounmpo      225                225             225  225  225
# Luka Doncic                210                210             210  210  210
# Jayson Tatum               209                209             209  209  209
# Trae Young                 189                189             189  189  189
# ...                        ...                ...             ...  ...  ...
# Dennis Schroder             67                 67              48   67   67
# Myles Turner                65                 65              65   65   65
# Tyrese Maxey                65                 65              62   65   65
# Brook Lopez                 64                 64              64   64   64
# Steven Adams                64                 64              64   64   64
#
#                        FGA  FG_PCT  FG3M  FG3A  FTM  ...  DREB  REB  AST  STL  \
# PLAYER_NAME                                          ...
# Nikola Jokic           234     234   234   234  234  ...   234  234  234  234
# Giannis Antetokounmpo  225     225   225   225  225  ...   225  225  225  225
# Luka Doncic            210     210   210   210  210  ...   210  210  210  210
# Jayson Tatum           209     209   209   209  209  ...   209  209  209  209
# Trae Young             189     189   189   189  189  ...   189  189  189  189
# ...                    ...     ...   ...   ...  ...  ...   ...  ...  ...  ...
# Dennis Schroder         67      67    67    67   67  ...    67   67   67   67
# Myles Turner            65      65    65    65   65  ...    65   65   65   65
# Tyrese Maxey            65      65    65    65   65  ...    65   65   65   65
# Brook Lopez             64      64    64    64   64  ...    64   64   64   64
# Steven Adams            64      64    64    64   64  ...    64   64   64   64
#
#                        BLK   TO   PF  PTS  PLUS_MINUS  GAME_SCORE
# PLAYER_NAME
# Nikola Jokic           234  234  234  234         234         234
# Giannis Antetokounmpo  225  225  225  225         225         225
# Luka Doncic            210  210  210  210         210         210
# Jayson Tatum           209  209  209  209         209         209
# Trae Young             189  189  189  189         189         189
# ...                    ...  ...  ...  ...         ...         ...
# Dennis Schroder         67   67   67   67          67          67
# Myles Turner            65   65   65   65          65          65
# Tyrese Maxey            65   65   65   65          65          65
# Brook Lopez             64   64   64   64          64          64
# Steven Adams            64   64   64   64          64          64
#
# [100 rows x 23 columns]

# %% [markdown]
# From 2020-2022, which players averaged the highest amount of game_score(in top 5 appearances only) when they played?

# %%
highest_avg_game_score = best_players_by_game_score.groupby('PLAYER_NAME').mean().sort_values(by = 'GAME_SCORE', ascending = False)
# Out:
# /var/folders/lz/89b0m93557x4pjgtj7v1dcpc0000gn/T/ipykernel_65222/1913315402.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   highest_avg_game_score = best_players_by_game_score.groupby('PLAYER_NAME').mean().sort_values(by = 'GAME_SCORE', ascending = False)

# %% [markdown]
# For players that are at least in the top 100 in games played in which they've had a top 5 game score, find the ones that have the highest average

# %% [markdown]
# To do this, we make go through the highest_game_score DataFrame and locate the player's names and look through the highest_avg_game_score DataFrame, which contains data on the average game_score as well as the average stats that the players contained in the games they played. By sorting through the players that had the most games in the top 5 of game score per game, we make sure that we don't have outlying players who may have only played 1 or 2 excellent games with the rest of their games being below average(meaning they didn't make the top 5 of a game)

# %%
best_players = pd.DataFrame(columns = highest_avg_game_score.columns)
for player in game_score_players.index: 
    if player in highest_avg_game_score.index:
            best_players = pd.concat([best_players, pd.DataFrame(highest_avg_game_score.loc[player]).T])

best_players['GAMES'] = game_score_players.loc[best_players.index].get('GAME_ID')

# %%
top_10_best_players = best_players.sort_values('GAME_SCORE', ascending = False).head(10).index

# %% [markdown]
# Just judging from average game score and how the amount of the times that each player did in the games they played(top 5 in game score in their games), it seems that the best and most consistent players in the league are Giannis Antetokounmpo, Joel Embiid, Nikola Jokic, Damian Lillard, Luka Doncic, Anthony Davis, James Harden, Kevin Durant, Stephen Curry, and Trae Young. But is this actually true? So I tested this with graphs detailing how well these players actually played and how their charts and plays may be misleading or false

# %%
 best_players
# Out:
#                              FGM        FGA    FG_PCT      FG3M      FG3A  \
# Nikola Jokic           10.064103  17.410256  0.591944  1.380342  3.653846
# Giannis Antetokounmpo  10.791111  19.462222  0.559893  1.044444  3.711111
# Luka Doncic            10.385714  21.623810  0.480252  3.090476  8.628571
# Jayson Tatum           10.081340  20.842105  0.486148  3.478469  8.636364
# Trae Young              9.423280  20.365079  0.465519  3.031746  8.037037
# ...                          ...        ...       ...       ...       ...
# Dennis Schroder         7.820896  15.029851  0.527313  2.164179  4.820896
# Myles Turner            6.753846  11.153846  0.610123  2.092308  4.353846
# Tyrese Maxey            8.492308  15.430769  0.564569  2.630769  5.230769
# Brook Lopez             7.234375  12.296875  0.606578  2.031250  4.734375
# Steven Adams            5.328125   8.156250  0.665422  0.000000  0.046875
#
#                             FTM        FTA      OREB       DREB        REB  \
# Nikola Jokic           5.012821   6.008547  2.700855   9.021368  11.722222
# Giannis Antetokounmpo  7.262222  10.702222  2.053333  10.195556  12.248889
# Luka Doncic            5.995238   8.252381  0.885714   7.923810   8.809524
# Jayson Tatum           5.846890   6.894737  0.918660   7.047847   7.966507
# Trae Young             8.179894   9.121693  0.698413   2.973545   3.671958
# ...                         ...        ...       ...        ...        ...
# Dennis Schroder        4.253731   4.940299  0.477612   3.358209   3.835821
# Myles Turner           2.923077   3.800000  1.815385   6.676923   8.492308
# Tyrese Maxey           3.861538   4.400000  0.353846   3.261538   3.615385
# Brook Lopez            2.734375   3.265625  2.156250   3.750000   5.906250
# Steven Adams           2.375000   4.218750  5.765625   6.125000  11.890625
#
#                             AST       STL       BLK        TO        PF  \
# Nikola Jokic           7.957265  1.414530  0.777778  3.457265  2.799145
# Giannis Antetokounmpo  5.724444  0.995556  1.182222  3.426667  3.111111
# Luka Doncic            8.623810  1.171429  0.533333  4.147619  2.414286
# Jayson Tatum           4.464115  1.162679  0.775120  2.803828  2.167464
# Trae Young             9.804233  0.862434  0.164021  3.968254  1.761905
# ...                         ...       ...       ...       ...       ...
# Dennis Schroder        5.805970  1.089552  0.238806  2.417910  2.358209
# Myles Turner           1.369231  0.876923  2.846154  1.400000  3.015385
# Tyrese Maxey           4.553846  1.015385  0.430769  1.276923  2.030769
# Brook Lopez            0.953125  0.703125  2.078125  0.937500  2.171875
# Steven Adams           3.281250  1.000000  1.015625  1.468750  1.796875
#
#                              PTS  PLUS_MINUS  GAME_SCORE  GAMES
# Nikola Jokic           26.521368    4.863248   26.307265    234
# Giannis Antetokounmpo  29.888889    6.608889   27.612889    225
# Luka Doncic            29.857143    3.290476   25.242857    210
# Jayson Tatum           29.488038    8.000000   23.266986    209
# Trae Young             30.058201    3.735450   24.496825    189
# ...                          ...         ...         ...    ...
# Dennis Schroder        22.059701    3.820896   18.243284     67
# Myles Turner           18.523077    4.107692   18.263077     65
# Tyrese Maxey           23.476923    6.000000   19.929231     65
# Brook Lopez            19.234375    8.671875   17.385938     64
# Steven Adams           13.031250    7.953125   17.884375     64
#
# [100 rows x 19 columns]

# %% [markdown]
# But what other ways can we calculate how valuable a player is, either offensively or defensively? To start, we can calculate how efficient certain players are by generating their points per possession. To do this, we have to calculate how many opsessions there are in a game, which can be theoretically calculated by using the formula of TPoss = FGAt + 0.44 * FTAt - OREBt + TO. Since FGAm, FTA, and TOs are typically how a posession ends, they are counted. For Free Throws, you can either shoot 1, 2, or up to 3 depending on the possession so 0.44 is the typical number since 3 pointers are rarer than 2s and 1s. Finally, Offensive Rebounds reset posessions and keep the possession to the same team
