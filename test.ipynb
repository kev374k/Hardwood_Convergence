# %%
import numpy as np
import pandas as pd

# %%
stats = pd.read_csv('files/FINAL_STATS/final_player_stats.csv')

# %%
stats
# Out:
#                  Player Pos  Age   Tm   G   PER    TS%   3PAr    FTr  ORB%  \
# 0            A.C. Green  PF   27  LAL  82  13.8  0.556  0.101  0.557  11.3
# 1          Ron Anderson  SF   32  PHI  82  15.5  0.524  0.041  0.188   5.0
# 2      Rolando Blackman  SG   31  DAL  80  16.6  0.545  0.087  0.248   2.4
# 3         Rodney McCray  PF   29  DAL  74  14.6  0.551  0.057  0.292   6.8
# 4          Chuck Person  SF   26  IND  80  16.1  0.553  0.165  0.186   5.6
# ...                 ...  ..  ...  ...  ..   ...    ...    ...    ...   ...
# 14692        Kyle Lowry  PG   35  MIA  63  15.0  0.600  0.609  0.278   1.8
# 14693      Steven Adams   C   28  MEM  76  17.6  0.560  0.003  0.518  17.9
# 14694        Kyle Kuzma  PF   26  WAS  66  15.2  0.547  0.401  0.234   3.6
# 14695     Tyler Johnson  PG   29  SAS   6   7.1  0.425  0.650  0.000   3.5
# 14696    Sharife Cooper  PG   20  ATL  13  -5.4  0.250  0.429  0.000   0.0
#
#        ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
centers = stats[(stats.get('Pos') == "C") & (stats.get('Year') == 2022)]

# %%
centers.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%',
#        'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
#        'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Year', 'Rank', 'Pts Won',
#        'Pts Max', 'Share', 'Team', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
centers['TS%'].median()
# Out:
# 0.596

# %%
pgs = stats[(stats.get('Pos') == "PG") & (stats.get('Year') == 2022)]

# %%
pgs['TS%'].median()
# Out:
# 0.5245
